# %%
import numpy as np
import pandas as pd
from pandas.core.interchange.dataframe_protocol import DataFrame

# %%
df=pd.DataFrame(['one','two','three','four','five','six','seven','eight',],index=['one','two','three','four','five','six','seven','d'])

# %%
data2=pd.Series(['mehid','alei','mehidd','aliw','mehi3d','agli'])

# %%
print(df)
